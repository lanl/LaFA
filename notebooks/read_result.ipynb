# %%
import pandas as pd
import pickle
import os
import seaborn as sns
from matplotlib import pyplot as plt

import file_name_gens

OUTPUT_PATH = 'log'
NAME = 'Synthetic_PGD_Linf_Implicit'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters           in       out rec      out fe   duration  \
# 0  0.00   0.01         40          0.0  0.0013071744         0.0  57.580394
# 0  0.01   0.01         40  0.016188378   0.020678619  0.13447651  54.848402
# 0  0.02   0.01         40   0.03212499   0.063854985   0.4785779  59.186299
# 0  0.03   0.01         40   0.04367206    0.06806351   0.5016345  58.714775
# 0  0.04   0.01         40  0.057786178     0.0778633  0.68336177  59.901897
# 0  0.05   0.01         40   0.07226483   0.089576595   0.6758817  60.714248
# 0  0.06   0.01         40   0.08745003    0.10252884  0.71188086  63.989137
# 0  0.07   0.01         40  0.100662015     0.1095772   0.7093224  57.290094
# 0  0.08   0.01         40   0.11498961    0.12114983   0.6864076  58.215337
# 0  0.09   0.01         40   0.13750938    0.16640297   0.7823059  64.042719
#
#       memory  Implicit gradient  norm  NMF iters  Seed
# 0  261869568               True  Linf       2000  2711
# ...

# %%
# with open(SAVE_NAME, 'wb') as logfile:
#     pickle.dump(df, logfile)

# %%
NAME = 'Synthetic_PGD_Linf_BackProp'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters           in       out rec      out fe    duration  \
# 0  0.00   0.01         40          0.0  0.0013071744         0.0  101.207389
# 0  0.01   0.01         40    0.0181422   0.025418496  0.22334744  100.947935
# 0  0.02   0.01         40   0.03069345    0.05323377   0.4480168  100.389699
# 0  0.03   0.01         40   0.04429162    0.06106488  0.36682194  100.768108
# 0  0.04   0.01         40  0.052525885    0.07239647   0.6564418  103.581582
# 0  0.05   0.01         40   0.06963441    0.07934445  0.62372106  104.364318
# 0  0.06   0.01         40   0.07455903    0.09028089  0.66533273  104.100553
# 0  0.07   0.01         40  0.093675695    0.10294199   0.6770388  101.298789
# 0  0.08   0.01         40  0.097009055    0.10685946   0.6982811   97.224545
# 0  0.09   0.01         40   0.11000428    0.12396585   0.6928507   95.830443
#
#        memory  Implicit gradient  norm  NMF iters  Seed
# 0  1044613632              False  Linf       2000  2711
# ...

# %%
OUTPUT_PATH = 'log'
NAME = 'Synthetic_PGD_L2_Implicit'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters           in       out rec      out fe   duration  \
# 0  0.00   0.01         40          0.0  0.0013071744         0.0  66.047127
# 0  0.01   0.01         40  0.009989711  0.0095614875  0.08273012  65.379997
# 0  0.02   0.01         40  0.019965671   0.020462876  0.09700138  63.538348
# 0  0.03   0.01         40  0.029853161     0.0522441  0.56259745  63.819979
# 0  0.04   0.01         40   0.03983291   0.067361616  0.57912767  65.504191
# 0  0.05   0.01         40   0.04988218    0.07457762   0.6827004  61.743201
# 0  0.06   0.01         40  0.059832856    0.08134465   0.6505037  63.250186
# 0  0.07   0.01         40  0.069878206    0.08852708   0.7077003  59.687482
# 0  0.08   0.01         40  0.079929836    0.09582869   0.6912947  59.507675
# 0  0.09   0.01         40   0.08984699    0.10506615  0.68037754  58.570640
# 0  0.10   0.01         40  0.099916555    0.11370641   0.7456717  58.969438
# ...

# %%
OUTPUT_PATH = 'log'
NAME = 'Synthetic_PGD_L2_BackProp'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters           in       out rec      out fe    duration  \
# 0  0.00   0.01         40          0.0  0.0013071744         0.0  113.278738
# 0  0.01   0.01         40  0.009999844   0.009669451  0.06577885  112.878649
# 0  0.02   0.01         40  0.019916615    0.03830868  0.43991897  111.476580
# 0  0.03   0.01         40  0.029999983    0.06116058  0.53274125  109.094507
# 0  0.04   0.01         40   0.03992041     0.0648527   0.5087195  108.120007
# 0  0.05   0.01         40   0.04984242     0.0697617   0.6437407  108.124721
# 0  0.06   0.01         40   0.05999922    0.07972456   0.6577456  108.100563
# 0  0.07   0.01         40   0.06987733    0.08361921  0.47499883  108.361840
# 0  0.08   0.01         40         0.08    0.09212331   0.6781569  108.193834
# 0  0.09   0.01         40  0.089999996   0.105189756   0.6818642  108.379604
# 0  0.10   0.01         40          0.1     0.1071462  0.66095936  108.208381
# ...

# %%
OUTPUT_PATH = 'log'
NAME = 'WTSI_PGD_Linf_Implicit'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 5
#       2 NAME = 'WTSI_PGD_Linf_Implicit'
#       3 SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'
# ----> 5 df = pd.read_pickle(SAVE_NAME)
#       6 df
#
# File ~/.conda/envs/minhvu121/lib/python3.12/site-packages/pandas/io/pickle.py:185, in read_pickle(filepath_or_buffer, compression, storage_options)
#     123 """
#     124 Load pickled pandas object (or any object) from file.
#     125
#    (...)
#     182 4    4    9
#     183 """
#     184 excs_to_catch = (AttributeError, ImportError, ModuleNotFoundError, TypeError)
# --> 185 with get_handle(
#     186     filepath_or_buffer,
#     187     "rb",
#     188     compression=compression,
#     189     is_text=False,
#     190     storage_options=storage_options,
#     191 ) as handles:
#     192     # 1) try standard library Pickle
# ...

# %%
OUTPUT_PATH = 'log'
NAME = 'WTSI_PGD_Linf_BackProp'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters          in      out rec      out fe   duration  \
# 0  0.00   0.01         40         0.0  0.015210481  0.02802034  60.244462
# 0  0.01   0.01         40  0.24548946   0.22970301  0.51100636  59.882267
# 0  0.02   0.01         40  0.51133037     0.512856   0.7902195  59.882159
# 0  0.03   0.01         40   0.7607736   0.75262624   0.9446396  59.818610
# 0  0.04   0.01         40   1.0126598    1.0028871   1.1125896  59.700159
# 0  0.05   0.01         40   1.3334278    1.3419851   1.2414272  58.589833
# 0  0.06   0.01         40   1.5548911    1.5637356   1.4580842  57.771212
# 0  0.07   0.01         40   1.7465594    1.8396028   1.5376284  57.548356
# 0  0.08   0.01         40   1.9741431    1.9580891   1.6013108  57.679796
# 0  0.09   0.01         40   2.2178667    2.3228362   1.7878672  57.662842
#
#      memory  Implicit gradient  norm  NMF iters  Seed
# 0  77115904              False  Linf       1000  2711
# ...

# %%
OUTPUT_PATH = 'log'
NAME = 'WTSI_PGD_L2_Implicit'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters           in      out rec      out fe   duration  \
# 0  0.00   0.01         40          0.0  0.015210481  0.02802034  35.272156
# 0  0.01   0.01         40  0.009933587  0.021752356  0.18113178  34.999815
# 0  0.02   0.01         40  0.019416785  0.027615545  0.16661587  35.136588
# 0  0.03   0.01         40   0.02892286  0.032767225   0.2407415  35.130675
# 0  0.04   0.01         40  0.038201828  0.040479504  0.25588048  35.126661
# 0  0.05   0.01         40  0.049751397  0.047427893   0.2671336  35.240317
# 0  0.06   0.01         40  0.056305192   0.05445065  0.29340222  35.326932
# 0  0.07   0.01         40   0.06580917  0.065801494   0.3324613  35.228575
# 0  0.08   0.01         40   0.07961568  0.073032096  0.30042735  35.174509
# 0  0.09   0.01         40   0.08294385   0.07892537    0.355259  35.353189
# 0  0.10   0.01         40  0.094864964   0.08991264  0.38968867  35.331866
# ...

# %%
OUTPUT_PATH = 'log'
NAME = 'WTSI_PGD_L2_BackProp'
SAVE_NAME = f'{OUTPUT_PATH}/{NAME}.pkl'

df = pd.read_pickle(SAVE_NAME)
df
# Out:
#     eps  alpha  pgd iters           in      out rec      out fe   duration  \
# 0  0.00   0.01         40          0.0  0.015210481  0.02802034  50.078269
# 0  0.01   0.01         40  0.009932283  0.022570401  0.20893265  49.718160
# 0  0.02   0.01         40   0.01999947   0.02356095  0.18074681  49.687569
# 0  0.03   0.01         40   0.02993959  0.036887806   0.2524607  49.638421
# 0  0.04   0.01         40         0.04   0.03852493  0.24513286  49.686539
# 0  0.05   0.01         40   0.04980055  0.047463015    0.284708  49.775256
# 0  0.06   0.01         40         0.06  0.055755626  0.30901423  49.732758
# 0  0.07   0.01         40         0.07   0.06689905  0.33337393  49.740087
# 0  0.08   0.01         40         0.08   0.07558542  0.35055473  49.738139
# 0  0.09   0.01         40  0.089999996  0.081696235  0.35572925  49.737865
# 0  0.10   0.01         40          0.1   0.09033746  0.37354806  49.260051
# ...
